# %% [markdown]
# # SOC 210B Assignment 4
# _By M. Nolan Gray_

# %%
# Importing libraries, checking out the dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
dtafile = './Data/nlsw88.dta'
df = pd.read_stata(dtafile)
df.head(5)
# Out:
#    idcode  age   race  married  never_married  grade          collgrad  south  \
# 0       1   37  black   single              0   12.0  not college grad      0
# 1       2   37  black   single              0   12.0  not college grad      0
# 2       3   42  black   single              1   12.0  not college grad      0
# 3       4   43  white  married              0   17.0      college grad      0
# 4       6   42  white  married              0   12.0  not college grad      0
#
#    smsa  c_city                industry  occupation     union       wage  \
# 0  SMSA       0  Transport/Comm/Utility  Operatives     union  11.739125
# 1  SMSA       1           Manufacturing   Craftsmen     union   6.400963
# 2  SMSA       1           Manufacturing       Sales       NaN   5.016723
# 3  SMSA       0   Professional Services       Other     union   9.033813
# 4  SMSA       0           Manufacturing  Operatives  nonunion   8.083731
#
#    hours    ttl_exp     tenure
# 0   48.0  10.333334   5.333333
# 1   40.0  13.621795   5.250000
# 2   40.0  17.730770   1.250000
# 3   42.0  13.211537   1.750000
# 4   48.0  17.820513  17.750000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2246 entries, 0 to 2245
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   idcode         2246 non-null   int16
#  1   age            2246 non-null   int8
#  2   race           2246 non-null   category
#  3   married        2246 non-null   category
#  4   never_married  2246 non-null   int8
#  5   grade          2244 non-null   float64
#  6   collgrad       2246 non-null   category
#  7   south          2246 non-null   int8
#  8   smsa           2246 non-null   category
#  9   c_city         2246 non-null   int8
#  10  industry       2232 non-null   category
#  11  occupation     2237 non-null   category
#  12  union          1878 non-null   category
#  13  wage           2246 non-null   float32
#  14  hours          2242 non-null   float64
#  15  ttl_exp        2246 non-null   float32
#  16  tenure         2231 non-null   float32
# dtypes: category(7), float32(3), float64(2), int16(1), int8(4)
# memory usage: 109.1 KB

# %% [markdown]
# ## Question 1

# %%
# Counts for categorical variables
for col in df.select_dtypes(['category']):
    print(df[col].value_counts(), "\n")
# Out:
# white    1637
# black     583
# other      26
# Name: race, dtype: int64
#
# married    1442
# single      804
# Name: married, dtype: int64
#
# not college grad    1714
# college grad         532
# Name: collgrad, dtype: int64
#
# SMSA       1581
# nonSMSA     665
# Name: smsa, dtype: int64
#
# Professional Services      824
# Manufacturing              367
# Wholesale/Retail Trade     333
# Finance/Ins/Real Estate    192
# Public Administration      176
# Personal Services           97
# Transport/Comm/Utility      90
# Business/Repair Svc         86
# Construction                29
# Ag/Forestry/Fisheries       17
# Entertainment/Rec Svc       17
# Mining                       4
# Name: industry, dtype: int64
#
# Sales                     726
# Professional/technical    317
# Laborers                  286
# Managers/admin            264
# Operatives                246
# Other                     187
# Clerical/unskilled        102
# Craftsmen                  53
# Transport                  28
# Service                    16
# Farm laborers               9
# Household workers           2
# Farmers                     1
# Name: occupation, dtype: int64
#
# nonunion    1417
# union        461
# Name: union, dtype: int64

# %%
# Continuous variable means and standard deviations
for col in df.select_dtypes(['float64','float32']):
    print(df[col].name,"Mean: ",df[col].mean(), "Standard deviation: ", df[col].std(), "\n")
# Out:
# grade Mean:  13.098930481283423 Standard deviation:  2.5212460945811084
#
# wage Mean:  7.766931056976318 Standard deviation:  5.755528450012207
#
# hours Mean:  37.218108831400535 Standard deviation:  10.509135117595548
#
# ttl_exp Mean:  12.534981727600098 Standard deviation:  4.610212326049805
#
# tenure Mean:  5.977848529815674 Standard deviation:  5.510325908660889

# %%
# I probably could have written a fancier loop that included
# age w/o all those pesky dummy variables, but I'm a dummy myself
print(df['age'].name,"Mean: ",df[col].mean(), "Standard deviation: ", df[col].std(), "\n")
# Out:
# age Mean:  5.977848529815674 Standard deviation:  5.510325908660889

# %% [markdown]
# ## Question 2

# %%
# These are the explanatory variables
X = df[['collgrad','union','ttl_exp','race']]

# %%
# Race needs to be turned into a dummy; 
# you will notice White is the reference category.
X = pd.get_dummies(data=X, drop_first=True)
X.head(5)
# Out:
#      ttl_exp  collgrad_college grad  union_union  race_black  race_other
# 0  10.333334                      0            1           1           0
# 1  13.621795                      0            1           1           0
# 2  17.730770                      0            0           1           0
# 3  13.211537                      1            1           0           0
# 4  17.820513                      0            0           0           0

# %%
X1 = X
y1 = df['wage']
X1 = sm.add_constant(X1)
reg1 = sm.OLS(y1, X1).fit()
reg1.summary()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   wage   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     70.68
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):           7.88e-69
# Time:                        06:48:33   Log-Likelihood:                -6952.8
# No. Observations:                2246   AIC:                         1.392e+04
# Df Residuals:                    2240   BIC:                         1.395e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     3.4530      0.336     10.281      0.000       2.794       4.112
# ttl_exp                   0.2980      0.025     12.051      0.000       0.250       0.347
# collgrad_college grad     3.1028      0.270     11.500      0.000       2.574       3.632
# union_union               0.6381      0.283      2.254      0.024       0.083       1.193
# race_black               -1.1126      0.260     -4.275      0.000      -1.623      -0.602
# race_other                0.0724      1.059      0.068      0.945      -2.005       2.150
# ==============================================================================
# Omnibus:                     1732.959   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32576.249
# Skew:                           3.579   Prob(JB):                         0.00
# Kurtosis:                      20.230   Cond. No.                         126.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# So the regression formula is *y = 3.45 + 0.30(x0) + 3.10(x1) + 0.64(x2) - 1.11(x3) + 0.07(x4), where:
# * x0 = ttl_exp
# * x1 = collgrad
# * x2 = union
# * x3 = race_black
# * x4 = race_other (Not significant!)
#
# So the formula for a black woman who is a unionized college graduate with 10 years of experience would have a predicted wage of:
# * 3.45 + 0.30(10) + 3.10(1) + 0.64(1) - 1.11(1) + 0.07(0) = *$9.08*
#
# Her older sister with 20 years of experience would have a predicted wage of:
# * 3.45 + 0.30(20) + 3.10(1) + 0.64(1) - 1.11(1) + 0.07(0) = *$12.08*

# %% [markdown]
# ## Question 3

# %%
# I'm going to use a different package that makes this easier.
import statsmodels.formula.api as smf

# %%
# First, let's test to make sure the output is consistent
model_interaction = smf.ols(formula='wage ~ X', data=df).fit()
summary = model_interaction.summary()
summary.tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# It is. Let's do some cleaning.
X.head(5)
# Out:
#      ttl_exp  collgrad_college grad  union_union  race_black  race_other
# 0  10.333334                      0            1           1           0
# 1  13.621795                      0            1           1           0
# 2  17.730770                      0            0           1           0
# 3  13.211537                      1            1           0           0
# 4  17.820513                      0            0           0           0

# %%
X = X.rename(columns = {'ttl_exp':'ttl_exp', 'collgrad_college grad':'coll_dummy', 'union_union':'union_dummy','race_black':'black','race_other':'other'})

# %%
X.head(5)
# Out:
#      ttl_exp  coll_dummy  union_dummy  black  other  idcode
# 0  10.333334           0            1      1      0       1
# 1  13.621795           0            1      1      0       2
# 2  17.730770           0            0      1      0       3
# 3  13.211537           1            1      0      0       4
# 4  17.820513           0            0      0      0       5

# %%
X["idcode"] = X.index + 1
X['idcode'] = X['idcode'].astype(np.int16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2246 entries, 0 to 2245
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   idcode         2246 non-null   int16
#  1   age            2246 non-null   int8
#  2   race           2246 non-null   category
#  3   married        2246 non-null   category
#  4   never_married  2246 non-null   int8
#  5   grade          2244 non-null   float64
#  6   collgrad       2246 non-null   category
#  7   south          2246 non-null   int8
#  8   smsa           2246 non-null   category
#  9   c_city         2246 non-null   int8
#  10  industry       2232 non-null   category
#  11  occupation     2237 non-null   category
#  12  union          1878 non-null   category
#  13  wage           2246 non-null   float32
#  14  hours          2242 non-null   float64
#  15  ttl_exp        2246 non-null   float32
#  16  tenure         2231 non-null   float32
# dtypes: category(7), float32(3), float64(2), int16(1), int8(4)
# memory usage: 109.1 KB

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2246 entries, 0 to 2245
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ttl_exp      2246 non-null   float32
#  1   coll_dummy   2246 non-null   uint8
#  2   union_dummy  2246 non-null   uint8
#  3   black        2246 non-null   uint8
#  4   other        2246 non-null   uint8
#  5   idcode       2246 non-null   int16
# dtypes: float32(1), int16(1), uint8(4)
# memory usage: 39.5 KB

# %%
merged = pd.merge(df, X, on="idcode",how='right')
merged.shape
# Out:
# (2246, 22)

# %%
merged.sample(10)
# Out:
#       idcode   age   race  married  never_married  grade          collgrad  \
# 1836    1837   NaN    NaN      NaN            NaN    NaN               NaN
# 208      209   NaN    NaN      NaN            NaN    NaN               NaN
# 1913    1914   NaN    NaN      NaN            NaN    NaN               NaN
# 1493    1494  38.0  white  married            0.0   12.0  not college grad
# 355      356  43.0  white  married            0.0   16.0      college grad
# 1429    1430   NaN    NaN      NaN            NaN    NaN               NaN
# 1810    1811   NaN    NaN      NaN            NaN    NaN               NaN
# 220      221  40.0  white  married            0.0   16.0      college grad
# 1283    1284  34.0  black  married            0.0   11.0  not college grad
# 214      215  36.0  white   single            1.0   16.0      college grad
#
#       south  smsa  c_city  ...     union      wage hours  ttl_exp_x  \
# 1836    NaN   NaN     NaN  ...       NaN       NaN   NaN        NaN
# 208     NaN   NaN     NaN  ...       NaN       NaN   NaN        NaN
# 1913    NaN   NaN     NaN  ...       NaN       NaN   NaN        NaN
# 1493    0.0  SMSA     0.0  ...     union  8.051530  40.0  16.134615
# 355     0.0  SMSA     0.0  ...  nonunion  7.318838  40.0  10.403847
# 1429    NaN   NaN     NaN  ...       NaN       NaN   NaN        NaN
# 1810    NaN   NaN     NaN  ...       NaN       NaN   NaN        NaN
# 220     0.0  SMSA     0.0  ...  nonunion  8.317226  35.0   9.256411
# 1283    0.0  SMSA     0.0  ...     union  5.716585  40.0  12.269231
# 214     0.0  SMSA     0.0  ...  nonunion  5.032206  40.0  15.852564
#
#          tenure  ttl_exp_y  coll_dummy  union_dummy  black  other
# 1836        NaN   3.826923           1            1      0      0
# 208         NaN   5.756410           0            0      0      0
# 1913        NaN   9.673077           0            0      0      0
# 1493  16.000000   8.884615           0            0      1      0
# 355    9.750000  13.589744           0            0      0      0
# 1429        NaN   5.730769           1            1      1      0
# 1810        NaN  13.647436           0            0      0      0
# 220    1.833333   9.166667           0            1      0      0
# 1283   9.416667  17.102564           0            0      0      0
# 214    3.750000  13.666667           1            1      0      0
#
# [10 rows x 22 columns]

# %%
print(df.iloc[1429])
# Out:
# idcode                          3282
# age                               34
# race                           black
# married                       single
# never_married                      0
# grade                           17.0
# collgrad                college grad
# south                              1
# smsa                            SMSA
# c_city                             1
# industry         Business/Repair Svc
# occupation                     Sales
# union                          union
# wage                        4.025765
# hours                           50.0
# ttl_exp                     5.730769
# tenure                      1.666667
# Name: 1429, dtype: object
